# %% [markdown]
# # Benchmark Visualizations

# %% [markdown]
# ## Setup

# %%
import ast
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Define color palette
sns.set(color_codes=True, style="white", context="talk", font_scale=1.5)
PALETTE = sns.color_palette("Set1")
sns.set_palette(PALETTE[1:5] + PALETTE[6:], n_colors=9)

# %%
def load_result(filename):
    """
    Loads results from specified file
    """
    inputs = open(filename, "r")
    lines = inputs.readlines()
    ls = []
    for line in lines:
        ls.append(ast.literal_eval(line))
    return ls

# %%
prefixes = ["dt/", "rf/", "ht/", "mf/", "sdt/", "sdf/", "csf/"]
legends = [
    "decision tree",
    "random forest",
    "hoeffding tree",
    "mondrian forest",
    "stream decision tree",
    "stream decision forest",
    "cascade stream forest",
]

# %% [markdown]
# ## Splice DNA (UCI)

# %%
acc_ls = []
for prefix in prefixes:
    acc_l = np.mean(load_result(prefix+"splice_acc.txt"), axis=0)
    acc_ls.append(acc_l)

# %%
n_train = range(100, 2400, 100)

fig, ax = plt.subplots(figsize=(10, 10))
ax.set_xlabel("Number of Training Samples", fontsize=20)
ax.set_ylabel("Average Accuracy", fontsize=20)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)

for i in range(7):
    plt.plot(n_train, acc_ls[i], label=legends[i], lw=5)
leg = plt.legend(bbox_to_anchor=(0.5, 0), bbox_transform=plt.gcf().transFigure,
                     ncol=2, loc='upper center')
leg.get_frame().set_linewidth(0.0)
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

# %% [markdown]
# ## Pen Digits (UCI)

# %%
acc_ls = []
for prefix in prefixes:
    acc_l = np.mean(load_result(prefix+"pendigits_acc.txt"), axis=0)
    acc_ls.append(acc_l)

# %%
n_train = range(100, 7500, 100)

fig, ax = plt.subplots(figsize=(10, 10))
ax.set_xlabel("Number of Training Samples", fontsize=20)
ax.set_ylabel("Average Accuracy", fontsize=20)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)

for i in range(7):
    plt.plot(n_train, acc_ls[i], label=legends[i], lw=5)
leg = plt.legend(bbox_to_anchor=(0.5, 0), bbox_transform=plt.gcf().transFigure,
                     ncol=2, loc='upper center')
leg.get_frame().set_linewidth(0.0)
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)

# %% [markdown]
# ## CIFAR-10

# %%
acc_ls = []
for prefix in prefixes:
    acc_l = np.mean(load_result(prefix+"cifar10_acc.txt"), axis=0)
    acc_ls.append(acc_l)

# %%
n_train = range(100, 50100, 100)

fig, ax = plt.subplots(figsize=(10, 10))
ax.set_xlabel("Number of Training Samples", fontsize=20)
ax.set_ylabel("Average Accuracy", fontsize=20)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)

for i in range(7):
    plt.plot(n_train, acc_ls[i], label=legends[i], lw=5)
leg = plt.legend(bbox_to_anchor=(0.5, 0), bbox_transform=plt.gcf().transFigure,
                     ncol=2, loc='upper center')
leg.get_frame().set_linewidth(0.0)
for legobj in leg.legendHandles:
    legobj.set_linewidth(5.0)
