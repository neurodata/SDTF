# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.datasets import load_iris

# load datasets
X, y = load_iris(return_X_y=True)

# %%
from numpy.random import permutation

p = permutation(len(X))

X_r = X[p]
y_r = y[p]

# %%
dt = DecisionTreeClassifier()
dt.fit(X_r,y_r)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(figsize=(20, 20))
plot_tree(dt, filled=True)
# Out:
# [Text(558.0, 996.6, 'X[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(472.15384615384613, 815.4000000000001, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(643.8461538461538, 815.4000000000001, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(343.38461538461536, 634.2, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(171.69230769230768, 453.0, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(85.84615384615384, 271.79999999999995, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(257.53846153846155, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(515.0769230769231, 453.0, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(429.23076923076917, 271.79999999999995, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(600.9230769230769, 271.79999999999995, 'X[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(515.0769230769231, 90.59999999999991, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(686.7692307692307, 90.59999999999991, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(944.3076923076923, 634.2, 'X[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(858.4615384615383, 453.0, 'X[0] <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(772.6153846153845, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(944.3076923076923, 271.79999999999995, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(1030.1538461538462, 453.0, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %%
predictions = dt.predict(X_r)

# %%
p_t = 0
p_f = 0
for i in range(150):
    if predictions[i]==y_r[i]:
        p_t+=1
    else:
        p_f+=1
        
print(p_t/150)
print(p_f/150)
# Out:
# 1.0
# 0.0

# %%
sdt = DecisionTreeClassifier()
sdt.fit(X_r[:50],y_r[:50])
# Out:
# DecisionTreeClassifier()

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plot_tree(sdt, filled=True)
# Out:
# [Text(446.4, 906.0, 'X[2] <= 2.45\ngini = 0.649\nsamples = 50\nvalue = [22, 13, 15]'),
#  Text(223.2, 543.6, 'gini = 0.0\nsamples = 22\nvalue = [22, 0, 0]'),
#  Text(669.5999999999999, 543.6, 'X[2] <= 4.9\ngini = 0.497\nsamples = 28\nvalue = [0, 13, 15]'),
#  Text(446.4, 181.19999999999993, 'gini = 0.0\nsamples = 13\nvalue = [0, 13, 0]'),
#  Text(892.8, 181.19999999999993, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 15]')]

# %%
sdt.fit(X_r[50:100],y_r[50:100],update_tree=True)
# Out:
# DecisionTreeClassifier()

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plot_tree(sdt, filled=True)
# Out:
# [Text(456.54545454545456, 978.48, 'X[2] <= 2.45\ngini = 0.649\nsamples = 50\nvalue = [22, 13, 15]'),
#  Text(202.9090909090909, 761.0400000000001, 'X[1] <= 2.65\ngini = 0.649\nsamples = 18\nvalue = [18, 0, 0]'),
#  Text(101.45454545454545, 543.6, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(304.3636363636364, 543.6, 'gini = 0.0\nsamples = 17\nvalue = [17, 0, 0]'),
#  Text(710.1818181818181, 761.0400000000001, 'X[2] <= 4.9\ngini = 0.497\nsamples = 28\nvalue = [0, 13, 15]'),
#  Text(507.27272727272725, 543.6, 'X[3] <= 1.65\ngini = 0.497\nsamples = 19\nvalue = [0, 16, 3]'),
#  Text(405.8181818181818, 326.1600000000001, 'gini = 0.0\nsamples = 15\nvalue = [0, 15, 0]'),
#  Text(608.7272727272727, 326.1600000000001, 'X[1] <= 3.1\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(507.27272727272725, 108.72000000000003, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(710.1818181818181, 108.72000000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(913.0909090909091, 543.6, 'X[2] <= 5.15\ngini = 0.497\nsamples = 13\nvalue = [0, 0, 13]'),
#  Text(811.6363636363636, 326.1600000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(1014.5454545454545, 326.1600000000001, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12]')]

# %%
sdt.fit(X_r[100:],y_r[100:],update_tree=True)
# Out:
# DecisionTreeClassifier()

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plot_tree(sdt, filled=True)
# Out:
# [Text(390.59999999999997, 996.6, 'X[2] <= 2.45\ngini = 0.649\nsamples = 50\nvalue = [22, 13, 15]'),
#  Text(111.6, 815.4000000000001, 'X[1] <= 2.65\ngini = 0.649\nsamples = 18\nvalue = [18, 0, 0]'),
#  Text(55.8, 634.2, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(167.39999999999998, 634.2, 'X[0] <= 4.75\ngini = 0.649\nsamples = 10\nvalue = [10, 0, 0]'),
#  Text(111.6, 453.0, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(223.2, 453.0, 'gini = 0.0\nsamples = 9\nvalue = [9, 0, 0]'),
#  Text(669.5999999999999, 815.4000000000001, 'X[2] <= 4.9\ngini = 0.497\nsamples = 28\nvalue = [0, 13, 15]'),
#  Text(446.4, 634.2, 'X[3] <= 1.65\ngini = 0.497\nsamples = 19\nvalue = [0, 16, 3]'),
#  Text(334.79999999999995, 453.0, 'X[2] <= 3.5\ngini = 0.497\nsamples = 19\nvalue = [0, 19, 0]'),
#  Text(279.0, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(390.59999999999997, 271.79999999999995, 'gini = 0.0\nsamples = 18\nvalue = [0, 18, 0]'),
#  Text(558.0, 453.0, 'X[1] <= 3.1\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(502.2, 271.79999999999995, 'X[3] <= 1.9\ngini = 0.375\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(446.4, 90.59999999999991, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(558.0, 90.59999999999991, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(613.8, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(892.8, 634.2, 'X[2] <= 5.15\ngini = 0.497\nsamples = 13\nvalue = [0, 0, 13]'),
#  Text(781.1999999999999, 453.0, 'X[3] <= 1.75\ngini = 0.497\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(725.4, 271.79999999999995, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(837.0, 271.79999999999995, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(1004.4, 453.0, 'X[2] <= 5.45\ngini = 0.497\nsamples = 12\nvalue = [0, 0, 12]'),
#  Text(948.5999999999999, 271.79999999999995, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(1060.2, 271.79999999999995, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10]')]

# %%
predictions = sdt.predict(X_r)

# %%
p_t = 0
p_f = 0
for i in range(150):
    if predictions[i]==y_r[i]:
        p_t+=1
    else:
        p_f+=1
        
print(p_t/150)
print(p_f/150)
# Out:
# 0.9866666666666667
# 0.013333333333333334
