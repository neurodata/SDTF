# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.datasets import load_iris

# load datasets
X, y = load_iris(return_X_y=True)

# %%
from numpy.random import permutation

p = permutation(len(X))

X_r = X[p]
y_r = y[p]

# %%
dt = DecisionTreeClassifier(max_leaf_nodes = 10)
dt.fit(X_r,y_r)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=10)

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(figsize=(20, 20))
plot_tree(dt, filled=True)
# Out:
# [Text(558.0, 996.6, 'X[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(472.15384615384613, 815.4000000000001, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(643.8461538461538, 815.4000000000001, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(343.38461538461536, 634.2, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(171.69230769230768, 453.0, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(85.84615384615384, 271.79999999999995, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(257.53846153846155, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(515.0769230769231, 453.0, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(429.23076923076917, 271.79999999999995, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(600.9230769230769, 271.79999999999995, 'X[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
# ...

# %%
predictions = dt.predict(X_r)

# %%
p_t = 0
p_f = 0
for i in range(150):
    if predictions[i]==y_r[i]:
        p_t+=1
    else:
        p_f+=1
        
print(p_t/150)
print(p_f/150)
# Out:
# 1.0
# 0.0

# %%
sdt = DecisionTreeClassifier(max_leaf_nodes = 10)
sdt.fit(X_r[:50],y_r[:50])
# Out:
# DecisionTreeClassifier(max_leaf_nodes=10)

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plot_tree(sdt, filled=True)
# Out:
# [Text(446.4, 951.3000000000001, 'X[2] <= 2.45\ngini = 0.666\nsamples = 50\nvalue = [17, 16, 17]'),
#  Text(223.2, 679.5, 'gini = 0.0\nsamples = 17\nvalue = [17, 0, 0]'),
#  Text(669.5999999999999, 679.5, 'X[3] <= 1.7\ngini = 0.5\nsamples = 33\nvalue = [0, 16, 17]'),
#  Text(446.4, 407.70000000000005, 'X[2] <= 5.35\ngini = 0.111\nsamples = 17\nvalue = [0, 16, 1]'),
#  Text(223.2, 135.89999999999998, 'gini = 0.0\nsamples = 16\nvalue = [0, 16, 0]'),
#  Text(669.5999999999999, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(892.8, 407.70000000000005, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 16]')]

# %%
sdt.fit(X_r[50:100],y_r[50:100],update_tree=True)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=10)

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plot_tree(sdt, filled=True)
# Out:
# [Text(456.54545454545456, 978.48, 'X[2] <= 2.45\ngini = 0.666\nsamples = 50\nvalue = [17, 16, 17]'),
#  Text(202.9090909090909, 761.0400000000001, 'X[3] <= 0.15\ngini = 0.666\nsamples = 17\nvalue = [17, 0, 0]'),
#  Text(101.45454545454545, 543.6, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(304.3636363636364, 543.6, 'gini = 0.0\nsamples = 13\nvalue = [13, 0, 0]'),
#  Text(710.1818181818181, 761.0400000000001, 'X[3] <= 1.7\ngini = 0.5\nsamples = 33\nvalue = [0, 16, 17]'),
#  Text(507.27272727272725, 543.6, 'X[2] <= 5.35\ngini = 0.111\nsamples = 17\nvalue = [0, 16, 1]'),
#  Text(405.8181818181818, 326.1600000000001, 'X[1] <= 2.1\ngini = 0.111\nsamples = 18\nvalue = [0, 18, 0]'),
#  Text(304.3636363636364, 108.72000000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(507.27272727272725, 108.72000000000003, 'gini = 0.0\nsamples = 17\nvalue = [0, 17, 0]'),
#  Text(608.7272727272727, 326.1600000000001, 'gini = 0.111\nsamples = 1\nvalue = [0, 0, 1]'),
# ...

# %%
sdt.fit(X_r[100:],y_r[100:],update_tree=True)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=10)

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plot_tree(sdt, filled=True)
# Out:
# [Text(387.5, 996.6, 'X[2] <= 2.45\ngini = 0.666\nsamples = 50\nvalue = [17, 16, 17]'),
#  Text(124.0, 815.4000000000001, 'X[3] <= 0.15\ngini = 0.666\nsamples = 17\nvalue = [17, 0, 0]'),
#  Text(62.0, 634.2, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(186.0, 634.2, 'X[0] <= 4.45\ngini = 0.666\nsamples = 16\nvalue = [16, 0, 0]'),
#  Text(124.0, 453.0, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(248.0, 453.0, 'gini = 0.0\nsamples = 14\nvalue = [14, 0, 0]'),
#  Text(651.0, 815.4000000000001, 'X[3] <= 1.7\ngini = 0.5\nsamples = 33\nvalue = [0, 16, 17]'),
#  Text(434.0, 634.2, 'X[2] <= 5.35\ngini = 0.111\nsamples = 17\nvalue = [0, 16, 1]'),
#  Text(372.0, 453.0, 'X[1] <= 2.1\ngini = 0.111\nsamples = 18\nvalue = [0, 18, 0]'),
#  Text(310.0, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(434.0, 271.79999999999995, 'X[2] <= 4.9\ngini = 0.111\nsamples = 16\nvalue = [0, 14, 2]'),
# ...

# %%
predictions = sdt.predict(X_r)

# %%
p_t = 0
p_f = 0
for i in range(150):
    if predictions[i]==y_r[i]:
        p_t+=1
    else:
        p_f+=1
        
print(p_t/150)
print(p_f/150)
# Out:
# 0.9733333333333334
# 0.02666666666666667
